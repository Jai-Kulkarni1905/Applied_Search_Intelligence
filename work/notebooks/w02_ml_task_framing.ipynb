# %% [markdown]
# <a href="https://colab.research.google.com/github/Jai-Kulkarni1905/Applied_Search_Intelligence/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Jai-Kulkarni1905/Applied_Search_Intelligence/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
# My lane is Content **Refresh Opportunity Scoring**, which is a **ranking task.**
#
# The goal is to rank content pages by their refresh opportunity so editors know which pages to review first.
# This directly supports the decision of where to spend limited content editing time.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
#
# The target is a **refresh opportunity score** that acts as a **proxy** for refresh priority.
#
# The starter dataset does not contain a future outcome showing whether a refresh would actually improve a page.
#
# So the score will use available performance signals to identify pages that appear most worth reviewing.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# The primary success metric is **Precision@K**.
#
# It measures how many of the top ranked pages are actually strong refresh opportunities.
#
# A higher Precision@K means the ranking is putting more useful pages in front of editors.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
#
# The unit of analysis is one content page.
#
# Each row represents one pseudonymized content item with its trailing 90 day performance data.
#
# dataset is used to compare pages and identify which ones have higher refresh priority.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
df = pd.read_csv('content_refresh_anonymized.csv')

display(
    df[
        [
            "content_id",
            "content_type",
            "impressions_90d",
            "clicks_90d",
            "ctr",
            "avg_position",
            "trend_direction"
        ]
    ].head()
)
# Out:
#              content_id     content_type  impressions_90d  clicks_90d   ctr  \
# 0  content_304f48230142  keyword article             3803          29  0.76
# 1  content_a1fb4e703a9e  keyword article            15320           7  0.05
# 2  content_9aa793d4d895  keyword article            12581          11  0.09
# 3  content_331d6c4de07b  keyword article            11751          58  0.49
# 4  content_d99b7a2d90ca  keyword article            19140          24  0.13
#
#    avg_position trend_direction
# 0          10.6            down
# 1          20.3            down
# 2          36.5            down
# 3           6.2          stable
# 4          44.0            down

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
# A fixed rule such as refreshing every page with low CTR would miss other useful signals.
#
# Refresh opportunity depends on several signals such as impressions, position, clicks and engagement.
#
# ML can combine these signals to rank pages more consistently than relying on one simple threshold.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
